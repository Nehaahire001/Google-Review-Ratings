# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/google_review_ratings.csv")

# %%
df
# Out:
#            User  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0        User 1        0.00        0.00        3.63        3.65        5.00
# 1        User 2        0.00        0.00        3.63        3.65        5.00
# 2        User 3        0.00        0.00        3.63        3.63        5.00
# 3        User 4        0.00        0.50        3.63        3.63        5.00
# 4        User 5        0.00        0.00        3.63        3.63        5.00
# ...         ...         ...         ...         ...         ...         ...
# 5451  User 5452        0.91        5.00        4.00        2.79        2.77
# 5452  User 5453        0.93        5.00        4.02        2.79        2.78
# 5453  User 5454        0.94        5.00        4.03        2.80        2.78
# 5454  User 5455        0.95        4.05        4.05        2.81        2.79
# 5455  User 5456        0.95        4.07        5.00        2.82        2.80
#
# ...

# %%
df.isnull().sum()
# Out:
# User              0
# Category 1        0
# Category 2        0
# Category 3        0
# Category 4        0
# Category 5        0
# Category 6        0
# Category 7        0
# Category 8        0
# Category 9        0
# Category 10       0
# Category 11       0
# Category 12       1
# Category 13       0
# Category 14       0
# Category 15       0
# Category 16       0
# Category 17       0
# Category 18       0
# Category 19       0
# Category 20       0
# Category 21       0
# Category 22       0
# Category 23       0
# Category 24       1
# Unnamed: 25    5454
# dtype: int64

# %%
df.drop("Unnamed: 25",axis=1,inplace=True)

# %%
df.drop("User",axis=1,inplace=True)

# %%
df.drop("Category 24",axis=1,inplace=True)

# %%
df.drop("Category 11",axis=1,inplace=True)

# %%
df=df.dropna(axis=1)  #To delete all the rows and columns with o and nan

# %%
linkage_data = linkage(df, method='ward', metric='euclidean')

# %%
linkage_data
# Out:
# array([[2.00000000e+00, 4.00000000e+00, 0.00000000e+00, 2.00000000e+00],
#        [1.33800000e+03, 1.34600000e+03, 0.00000000e+00, 2.00000000e+00],
#        [6.70000000e+02, 6.74000000e+02, 0.00000000e+00, 2.00000000e+00],
#        ...,
#        [1.09050000e+04, 1.09060000e+04, 1.52554623e+02, 2.15900000e+03],
#        [1.09010000e+04, 1.09070000e+04, 1.84166028e+02, 3.29700000e+03],
#        [1.09080000e+04, 1.09090000e+04, 2.09279392e+02, 5.45600000e+03]])

# %%
dendrogram(linkage_data)
plt.show()
